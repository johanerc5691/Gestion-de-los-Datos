# %% [markdown]
# IMPORTACION DE LIBRERIAS

# %%
import pandas as pd
import pandasql as ps

# %% [markdown]
# CARGA DE LOS DOS ARCHIVOS .XLSX

# %%
clientes = pd.read_excel('clientesT.xlsx')
transacciones = pd.read_excel('transaccionesT.xlsx')
